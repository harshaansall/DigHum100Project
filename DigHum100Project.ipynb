# %% [markdown]
# # Are NFL Players getting more athletic over time?

# %% [markdown]
# In this analysis, we will see if NFL players have gotten more athletic over time. To conduct this analysis, we will use a dataset from Kaggle that contains NFL player measurements from the NFL combine from 2000 until 2018.

# %% [markdown]
# •Harshaan Sall    •DigHum100     •Dr.Anderson    •6/5/21

# %%
# In this cell, I will import the libraries that I need to conduct the analysis and create visualizations.
import pandas as pd
import numpy as np
from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#In this cell, we will load in our data set as a table so we can begin to do some preliminary analyis. 
combine_data=pd.read_csv('combine_data_since_2000_PROCESSED_2018-04-26.csv')

# %%
#In this cell we will create a Table out of the data frame so we can use table methods learned from Data 8 in our analysis.
combine_data_table=Table.read_table('combine_data_since_2000_PROCESSED_2018-04-26.csv')
combine_data_table
# Out:
# Player           | Pos  | Ht   | Wt   | Forty | Vertical | BenchReps | BroadJump | Cone | Shuttle | Year | Pfr_ID     | AV   | Team                | Round | Pick
# John Abraham     | OLB  | 76   | 252  | 4.55  | nan      | nan       | nan       | nan  | nan     | 2000 | AbraJo00   | 26   | New York Jets       | 1     | 13
# Shaun Alexander  | RB   | 72   | 218  | 4.58  | nan      | nan       | nan       | nan  | nan     | 2000 | AlexSh00   | 26   | Seattle Seahawks    | 1     | 19
# Darnell Alford   | OT   | 76   | 334  | 5.56  | 25       | 23        | 94        | 8.48 | 4.98    | 2000 | AlfoDa20   | 0    | Kansas City Chiefs  | 6     | 188
# Kyle Allamon     | TE   | 74   | 253  | 4.97  | 29       | nan       | 104       | 7.29 | 4.49    | 2000 | nan        | 0    | nan                 | nan   | nan
# Rashard Anderson | CB   | 74   | 206  | 4.55  | 34       | nan       | 123       | 7.18 | 4.15    | 2000 | AndeRa21   | 6    | Carolina Panthers   | 1     | 23
# ...

# %% [markdown]
# In the following cell, we will modify our previous table and group together the years and the average 40 yard dash time per year. First, we must select the needed columns of Year and Forty, which represent the year and the 40 yard dash times. Next, we must filter the data to exclude nan values for players who did not run the 40 yard dash. Then, we will group the data to show average 40 yard dash times per year. Finally, we will create a plot of average 40 times over the years.

# %%
fortytimetable=combine_data_table.select('Year', 'Forty').where('Forty', are.above(4)).group('Year', np.average)
fortytimetable.plot('Year', 'Forty average')

# %% [markdown]
# The visualization above seems to show that average 40 times over the years has had a downward trend. In order to see if this is just due to chance, we will compare the average 40 times of the year 2000 and 2017 and conduct an A/B test to find the statistical significance of the difference.

# %%
#In this cell we will write code to conduct the A/B test.

# %% [markdown]
# Now, we will conduct a similar analysis of average bench press reps per year. We will begin by creating a visualization and then statistical analysis.

# %% [markdown]
# In the following cell, we will clean our data to only show the players who participated in the bench press. Next, we will create a new table that only contains year and bench press reps. Finally we will group our data to show the average bench press reps by the players for each year.

# %%
bench_data= combine_data_table.where('BenchReps', are.above(0)).select('Year','BenchReps').group('Year', np.average)
bench_data
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Year</th> <th>BenchReps average</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>2000</td> <td>20.64            </td>
#         </tr>
#         <tr>
#             <td>2001</td> <td>20.5287          </td>
#         </tr>
#         <tr>
#             <td>2002</td> <td>21.5172          </td>
#         </tr>
#         <tr>
#             <td>2003</td> <td>21.7333          </td>
#         </tr>
#         <tr>
#             <td>2004</td> <td>22.2708          </td>
#         </tr>
#         <tr>
#             <td>2005</td> <td>21.6382          </td>
#         </tr>
#         <tr>
#             <td>2006</td> <td>21.7465          </td>
#         </tr>
#         <tr>
#             <td>2007</td> <td>21.9817          </td>
#         </tr>
#         <tr>
#             <td>2008</td> <td>21.658           </td>
#         </tr>
#         <tr>
# ...

# %% [markdown]
# Now that we have a filtered dataset, we can create a visualization to show how the average number of bench press reps by NFL players has changed over the years.

# %%
bench_data.plot('Year','BenchReps average')

# %%
#In this cell, I will conduct an A/B test for bench press reps over the years to see if the difference is due to chance or if its statistically significant
